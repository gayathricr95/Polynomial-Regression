# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sns.set_style('whitegrid')
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv(r'C:\Users\CR GAYATHRI\Desktop\MachineLearning\Practice\Fish.csv')

# %%
data.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
data.shape
# Out:
# (159, 7)

# %%
data.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
# Species    159 non-null object
# Weight     159 non-null float64
# Length1    159 non-null float64
# Length2    159 non-null float64
# Length3    159 non-null float64
# Height     159 non-null float64
# Width      159 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
data.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
data.corr()
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
sns.heatmap(data.corr(), cmap = 'Accent', annot = True);

# %%
sns.pairplot(data)

# %%
data.isnull().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
sns.distplot(data.Weight)

# %%
plt.scatter(x = data.Length1, y = data.Weight)

# %%
sns.distplot(data.Length1)

# %%
plt.scatter(x = data.Length2, y = data.Weight)

# %%
sns.distplot(data.Length2)

# %%
plt.scatter(x = data.Length3, y = data.Weight)

# %%
sns.distplot(data.Length3)

# %%
data.Weight.quantile([0.25,0.75])
# Out:
# 0.25    120.0
# 0.75    650.0
# Name: Weight, dtype: float64

# %%
iqr = 650.0 - 120.0
iqr
# Out:
# 530.0

# %%
LB = 120.0 - (1.5*iqr)
LB
# Out:
# -675.0

# %%
UB = 120.0 + (1.5*iqr)
UB
# Out:
# 915.0

# %%
data.Weight.mean() + 2*data.Weight.std()
# Out:
# 1114.283048196126

# %%
data.Weight.mean() - 2*data.Weight.std()
# Out:
# -317.6302180074466

# %%
data[(data.Weight < -675.0) | (data.Weight > 915.0)]
# Out:
#      Species  Weight  Length1  Length2  Length3   Height   Width
# 29         0  1000.0     33.5     37.0     42.6  18.9570  6.6030
# 30         0   920.0     35.0     38.5     44.1  18.0369  6.3063
# 31         0   955.0     35.0     38.5     44.0  18.0840  6.2920
# 32         0   925.0     36.2     39.5     45.3  18.7542  6.7497
# 33         0   975.0     37.4     41.0     45.9  18.6354  6.7473
# 34         0   950.0     38.0     41.0     46.5  17.6235  6.3705
# 60         6  1000.0     37.3     40.0     43.5  12.3540  6.5250
# 121        2  1015.0     37.0     40.0     42.4  12.3808  7.4624
# 123        2  1100.0     39.0     42.0     44.6  12.8002  6.8684
# 124        2  1000.0     39.8     43.0     45.2  11.9328  7.2772
# 125        2  1100.0     40.1     43.0     45.5  12.5125  7.4165
# 126        2  1000.0     40.2     43.5     46.0  12.6040  8.1420
# 127        2  1000.0     41.1     44.0     46.6  12.4888  7.5958
# ...

# %%
plt.subplot(121)
sns.distplot(data.Weight)

plt.subplot(122)
sns.distplot(np.log(data.Weight))

plt.show();
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-89-2ca8ff4767b0> in <module>
#       3
#       4 plt.subplot(122)
# ----> 5 sns.distplot(np.log(data.Weight))
#       6
#       7 plt.show();
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
# ...

# %%
data['Species'].head()
# Out:
# 0    Bream
# 1    Bream
# 2    Bream
# 3    Bream
# 4    Bream
# Name: Species, dtype: object

# %%
sns.countplot(data.Species)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['Species'] = le.fit_transform(data['Species'])

# %%
data.Species
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 154    5
# 155    5
# 156    5
# 157    5
# 158    5
# Name: Species, Length: 159, dtype: int32

# %%
data.head()
# Out:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 0        0   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1        0   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2        0   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3        0   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4        0   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
data.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
cols = ['Species', 'Length1', 'Length2', 'Length3', 'Height',
       'Width']

# %%
x = data[cols]
y = data.Weight

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 6)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_
# Out:
# -588.5758824004768

# %%
model.coef_
# Out:
# array([ 34.96125558,  98.74325333, -18.75164914, -52.92191788,
#         56.24275418,  -1.77947607])

# %%
train_pred = model.predict(x_train)


test_pred = model.predict(x_test)

# %%
r2_score(y_train, train_pred)
# Out:
# 0.9061046235994752

# %%
r2_score(y_test, test_pred)
# Out:
# 0.8558020681371308

# %%
from sklearn import metrics

np.sqrt(metrics.mean_squared_error(y_train, train_pred))

np.sqrt(metrics.mean_squared_error(y_test, test_pred))
# Out:
# 102.62198188812528
# 150.8996179535613
